# %% [markdown]
# # Workflow widget

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# %matplotlib widget

# %%
from ess.reflectometry.gui import AmorBatchReductionGUI

# %%
gui = AmorBatchReductionGUI()
gui.widget
# Out:
# VBox(children=(Text(value='', description='Proposal no.:', layout=Layout(border_bottom='2px solid red', border…
